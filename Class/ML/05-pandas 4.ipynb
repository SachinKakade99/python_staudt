# %%
import pandas as pd

# %%
df = pd.read_csv('advertising.csv')

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df = pd.read_csv('weatherHistory.csv',)

# %%
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df[df['Temperature (C)'] ==df['Temperature (C)'].max()]
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 12759  2007-07-22 15:00:00.000 +0200   Clear        rain        39.905556
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 12759                 37.538889      0.13            23.5865
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 12759                   250.0            9.982         0.0
#
#        Pressure (millibars)                             Daily Summary
# 12759               1007.55  Partly cloudy starting in the afternoon.

# %%
df['Temperature (C)'].max()
# Out:
# 39.90555555555555

# %%
df['Temperature (C)'].std()
# Out:
# 9.551546320656923

# %%
df['Formatted Date'][df['Temperature (C)']==df['Temperature (C)'].max()]
# Out:
# 12759    2007-07-22 15:00:00.000 +0200
# Name: Formatted Date, dtype: object

# %%
df['Precip Type'][df['Humidity']==df['Humidity'].max()]
# Out:
# 319      rain
# 342      rain
# 390      rain
# 535      rain
# 536      rain
#          ...
# 95907    rain
# 96123    rain
# 96148    rain
# 96363    rain
# 96364    rain
# Name: Precip Type, Length: 2890, dtype: object

# %%
df['Daily Summary'][df['Humidity']==df['Humidity'].min()]
# Out:
# 19958    Partly cloudy starting in the morning continui...
# 28101    Mostly cloudy starting overnight continuing un...
# 28103    Mostly cloudy starting overnight continuing un...
# 28110               Mostly cloudy starting in the morning.
# 29627    Foggy starting overnight continuing until afte...
# 54840    Foggy starting in the morning continuing until...
# 54858    Foggy starting in the morning continuing until...
# 54870    Foggy starting overnight continuing until morn...
# 54872    Foggy starting overnight continuing until morn...
# 54873    Foggy starting overnight continuing until morn...
# 55086                    Mostly cloudy throughout the day.
# 55088                    Mostly cloudy throughout the day.
# 55349    Foggy starting in the morning continuing until...
# 55350    Foggy starting in the morning continuing until...
# 55352    Foggy starting in the morning continuing until...
# 55412                                Foggy in the evening.
# ...

# %%
df[df['Temperature (C)']>20]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 37     2006-04-10 13:00:00.000 +0200  Mostly Cloudy        rain
# 38     2006-04-10 14:00:00.000 +0200  Mostly Cloudy        rain
# 39     2006-04-10 15:00:00.000 +0200  Mostly Cloudy        rain
# 40     2006-04-10 16:00:00.000 +0200  Mostly Cloudy        rain
# 41     2006-04-10 17:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 37           20.044444                 20.044444      0.40            28.3682
# ...

# %%
df[(df['Temperature (C)']>20) & (df['Temperature (C)']<25)]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 37     2006-04-10 13:00:00.000 +0200  Mostly Cloudy        rain
# 38     2006-04-10 14:00:00.000 +0200  Mostly Cloudy        rain
# 39     2006-04-10 15:00:00.000 +0200  Mostly Cloudy        rain
# 40     2006-04-10 16:00:00.000 +0200  Mostly Cloudy        rain
# 41     2006-04-10 17:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96439  2016-09-09 10:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 37           20.044444                 20.044444      0.40            28.3682
# ...

# %%
df1 = pd.read_csv('weather.csv')

# %%
df1
# Out:
#       Data.Precipitation,"Date.Full","Date.Month","Date.Week of","Date.Year","Station.City","Station.Code","Station.Location","Station.State","Data.Temperature.Avg Temp","Data.Temperature.Max Temp","Data.Temperature.Min Temp","Data.Wind.Direction","Data.Wind.Speed"
# 0      0.0,"2016-01-03","1","3","2016","Birmingham","...
# 1      0.0,"2016-01-03","1","3","2016","Huntsville","...
# 2      0.16,"2016-01-03","1","3","2016","Mobile","MOB...
# 3      0.0,"2016-01-03","1","3","2016","Montgomery","...
# 4      0.01,"2016-01-03","1","3","2016","Anchorage","...
# ...                                                  ...
# 16738  0.08,"2017-01-01","1","1","2017","Casper","CPR...
# 16739  0.0,"2017-01-01","1","1","2017","Cheyenne","CY...
# 16740  0.0,"2017-01-01","1","1","2017","Lander","LND"...
# 16741  0.06,"2017-01-01","1","1","2017","Rawlins","RW...
# 16742  0.1,"2017-01-01","1","1","2017","Sheridan","SH...
#
# [16743 rows x 1 columns]

# %%
df2 = pd.read_csv('Bengaluru_House_Data.csv')

# %%
df2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df3 = df2[df2['total_sqft']==df2['total_sqft'].max()]

# %%
df3
# Out:
#                   area_type   availability     location   size  society  \
# 1369         Built-up  Area  Ready To Move  BEML Layout  2 BHK      NaN
# 5256   Super built-up  Area         19-Jan  Mailasandra  2 BHK  Hanar I
# 10519  Super built-up  Area  Ready To Move  Dommasandra  2 BHK      NaN
#
#       total_sqft  bath  balcony  price
# 1369         999   2.0      3.0  45.00
# 5256         999   2.0      1.0  43.66
# 10519        999   2.0      2.0  32.90

# %%
df3['location']
# Out:
# 1369     BEML Layout
# 5256     Mailasandra
# 10519    Dommasandra
# Name: location, dtype: object

# %%
df2['total_sqft']==1200
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13315    False
# 13316    False
# 13317    False
# 13318    False
# 13319    False
# Name: total_sqft, Length: 13320, dtype: bool

# %%
df2.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df2['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
df2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.set_index('Precip Type',inplace=True)

# %%
df.index
# Out:
# Index(['rain', 'rain', 'rain', 'rain', 'rain', 'rain', 'rain', 'rain', 'rain',
#        'rain',
#        ...
#        'rain', 'rain', 'rain', 'rain', 'rain', 'rain', 'rain', 'rain', 'rain',
#        'rain'],
#       dtype='object', name='Precip Type', length=96453)

# %%
df.reset_index(inplace=True)

# %%
df['Precip Type'].unique()
# Out:
# array(['rain', 'snow', nan], dtype=object)

# %%
df.set_index('Precip Type',inplace=True)

# %%
import numpy as np

# %%
df.loc[np.nan]
# Out:
#                             Formatted Date        Summary  Temperature (C)  \
# Precip Type
# NaN          2012-04-11 16:00:00.000 +0200  Mostly Cloudy        19.016667
# NaN          2012-04-11 18:00:00.000 +0200  Mostly Cloudy        17.850000
# NaN          2012-04-11 19:00:00.000 +0200  Mostly Cloudy        16.322222
# NaN          2012-04-11 21:00:00.000 +0200  Mostly Cloudy        12.566667
# NaN          2012-04-11 22:00:00.000 +0200  Mostly Cloudy        12.927778
# ...                                    ...            ...              ...
# NaN          2016-10-31 19:00:00.000 +0100  Mostly Cloudy         8.322222
# NaN          2016-10-31 20:00:00.000 +0100  Mostly Cloudy         7.627778
# NaN          2016-10-31 21:00:00.000 +0100  Mostly Cloudy         7.111111
# NaN          2016-10-31 22:00:00.000 +0100  Partly Cloudy         6.672222
# NaN          2016-10-31 23:00:00.000 +0100  Mostly Cloudy         6.322222
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df.loc[2]
# Out:
# Precip Type                                              rain
# Formatted Date                  2006-04-01 02:00:00.000 +0200
# Summary                                         Mostly Cloudy
# Temperature (C)                                      9.377778
# Apparent Temperature (C)                             9.377778
# Humidity                                                 0.89
# Wind Speed (km/h)                                      3.9284
# Wind Bearing (degrees)                                  204.0
# Visibility (km)                                       14.9569
# Loud Cover                                                0.0
# Pressure (millibars)                                  1015.94
# Daily Summary               Partly cloudy throughout the day.
# Name: 2, dtype: object

# %%
df4 = pd.read_csv('my_listcsv.csv')

# %%
df4
# Out:
#    Unnamed: 0 Joining Date               Designation   Name
# 0           0     1/1/2021  Senior Software Engineer   Arun
# 1           1     3/6/2021                        DS  Rahul
# 2           2     4/6/2022                        ML    Jon

# %%
df4.loc[0:1,'Joining Date':'Designation']
# Out:
#   Joining Date               Designation
# 0     1/1/2021  Senior Software Engineer
# 1     3/6/2021                        DS

# %%
df4.loc[0:2:2,'Unnamed: 0':'Name':2]
# Out:
#    Unnamed: 0               Designation
# 0           0  Senior Software Engineer
# 2           2                        ML

# %%
#iloc 

i integer location

# %%
df4
# Out:
#    Unnamed: 0 Joining Date               Designation   Name
# 0           0     1/1/2021  Senior Software Engineer   Arun
# 1           1     3/6/2021                        DS  Rahul
# 2           2     4/6/2022                        ML    Jon

# %%
df4.iloc[1:2]
# Out:
#    Unnamed: 0 Joining Date Designation   Name
# 1           1     3/6/2021          DS  Rahul

# %%
df4.loc[1:2]
# Out:
#    Unnamed: 0 Joining Date Designation   Name
# 1           1     3/6/2021          DS  Rahul
# 2           2     4/6/2022          ML    Jon

# %%
df4
# Out:
#    Unnamed: 0 Joining Date               Designation   Name
# 0           0     1/1/2021  Senior Software Engineer   Arun
# 1           1     3/6/2021                        DS  Rahul
# 2           2     4/6/2022                        ML    Jon

# %%
df4.iloc[1:3,1:4:2]
# Out:
#   Joining Date   Name
# 1     3/6/2021  Rahul
# 2     4/6/2022    Jon

# %%
df4[['Name','Joining Date']]
# Out:
#     Name Joining Date
# 0   Arun     1/1/2021
# 1  Rahul     3/6/2021
# 2    Jon     4/6/2022

# %%
df
# Out:
#       Precip Type                 Formatted Date        Summary  \
# 0            rain  2006-04-01 00:00:00.000 +0200  Partly Cloudy
# 1            rain  2006-04-01 01:00:00.000 +0200  Partly Cloudy
# 2            rain  2006-04-01 02:00:00.000 +0200  Mostly Cloudy
# 3            rain  2006-04-01 03:00:00.000 +0200  Partly Cloudy
# 4            rain  2006-04-01 04:00:00.000 +0200  Mostly Cloudy
# ...           ...                            ...            ...
# 96448        rain  2016-09-09 19:00:00.000 +0200  Partly Cloudy
# 96449        rain  2016-09-09 20:00:00.000 +0200  Partly Cloudy
# 96450        rain  2016-09-09 21:00:00.000 +0200  Partly Cloudy
# 96451        rain  2016-09-09 22:00:00.000 +0200  Partly Cloudy
# 96452        rain  2016-09-09 23:00:00.000 +0200  Partly Cloudy
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.drop([1,4,5])
# Out:
#       Precip Type                 Formatted Date        Summary  \
# 0            rain  2006-04-01 00:00:00.000 +0200  Partly Cloudy
# 2            rain  2006-04-01 02:00:00.000 +0200  Mostly Cloudy
# 3            rain  2006-04-01 03:00:00.000 +0200  Partly Cloudy
# 6            rain  2006-04-01 06:00:00.000 +0200  Partly Cloudy
# 7            rain  2006-04-01 07:00:00.000 +0200  Partly Cloudy
# ...           ...                            ...            ...
# 96448        rain  2016-09-09 19:00:00.000 +0200  Partly Cloudy
# 96449        rain  2016-09-09 20:00:00.000 +0200  Partly Cloudy
# 96450        rain  2016-09-09 21:00:00.000 +0200  Partly Cloudy
# 96451        rain  2016-09-09 22:00:00.000 +0200  Partly Cloudy
# 96452        rain  2016-09-09 23:00:00.000 +0200  Partly Cloudy
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.head(5)
# Out:
#   Precip Type                 Formatted Date        Summary  Temperature (C)  \
# 0        rain  2006-04-01 00:00:00.000 +0200  Partly Cloudy         9.472222
# 1        rain  2006-04-01 01:00:00.000 +0200  Partly Cloudy         9.355556
# 2        rain  2006-04-01 02:00:00.000 +0200  Mostly Cloudy         9.377778
# 3        rain  2006-04-01 03:00:00.000 +0200  Partly Cloudy         8.288889
# 4        rain  2006-04-01 04:00:00.000 +0200  Mostly Cloudy         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df[(df['Temperature (C)']) == (df['Temperature (C)']>20)].head(5)
# Out:
#      Precip Type                 Formatted Date   Summary  Temperature (C)  \
# 1581        snow  2006-12-13 21:00:00.000 +0100     Foggy              0.0
# 1602        snow  2006-12-14 18:00:00.000 +0100     Foggy              0.0
# 1667        snow  2006-12-17 11:00:00.000 +0100     Foggy              0.0
# 2057        snow  2006-12-31 17:00:00.000 +0100     Foggy              0.0
# 2678        snow  2006-02-27 14:00:00.000 +0100  Overcast              0.0
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1581                 -4.255556      0.96            14.2646
# 1602                 -3.533333      0.93            10.9319
# 1667                 -3.094444      0.93             9.2575
# 2057                 -2.605556      0.92             7.6475
# 2678                 -5.316667      0.63            20.6402
#
#       Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 1581                   210.0           0.3220         0.0
# ...
