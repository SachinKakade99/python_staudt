# %%
import pandas as pd

# %%
df  =  pd.read_csv('weather.csv')

# %%
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
#null values

# %%
df.isnull().sum()
# Out:
# Data.Precipitation           0
# Date.Full                    0
# Date.Month                   0
# Date.Week of                 0
# Date.Year                    0
# Station.City                 0
# Station.Code                 0
# Station.Location             0
# Station.State                0
# Data.Temperature.Avg Temp    0
# Data.Temperature.Max Temp    0
# Data.Temperature.Min Temp    0
# Data.Wind.Direction          0
# Data.Wind.Speed              0
# dtype: int64

# %%
df1 = pd.read_csv('test.csv')

# %%
df1
# Out:
#    Unnamed: 0    city  temp       date  humidity
# 0           0     NaN  34.0  2021/1/24        35
# 1           1  mumbai   NaN  2021/2/25        67
# 2           2     NaN  23.0  2021/3/26        97

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0    0
# city          2
# temp          1
# date          0
# humidity      0
# dtype: int64

# %%
df1['humidity'].unique()
# Out:
# array([35, 67, 97], dtype=int64)

# %%
df['Station.City'].unique()
# Out:
# array(['Birmingham', 'Huntsville', 'Mobile', 'Montgomery', 'Anchorage',
#        'Annette', 'Bethel', 'Bettles', 'Cold Bay', 'Cordova',
#        'Delta Junction/Ft Greely', 'Fairbanks', 'Gulkana', 'Homer',
#        'Iliamna', 'Juneau', 'Kenai', 'Ketchikan', 'King Salmon', 'Kodiak',
#        'Kotzebue', 'Mc Grath', 'Nome', 'Northway', 'Palmer', 'Petersburg',
#        'Puntilla Lake', 'Shemya', 'Sitka', 'Skagway', 'St Paul Island',
#        'Talkeetna', 'Tanana', 'Utqiagvik (Barrow)', 'Yakutat',
#        'Douglas Bisbee', 'Kingman', 'Phoenix', 'Tucson', 'Winslow',
#        'Fort Smith', 'Harrison', 'North Little Rock', 'Bakersfield',
#        'Bishop', 'China Lake', 'Concord', 'Eureka', 'Fresno', 'Hayward',
#        'Long Beach', 'Los Angeles', 'Red Bluff', 'Redding', 'Sacramento',
#        'Salinas', 'San Diego', 'San Francisco', 'Sandberg',
#        'Santa Barbara', 'Santa Maria', 'Stockton', 'Alamosa',
#        'Colorado Springs', 'Craig', 'Denver', 'Grand Junction', 'Pueblo',
# ...

# %%
df.dtypes
# Out:
# Data.Precipitation           float64
# Date.Full                     object
# Date.Month                     int64
# Date.Week of                   int64
# Date.Year                      int64
# Station.City                  object
# Station.Code                  object
# Station.Location              object
# Station.State                 object
# Data.Temperature.Avg Temp      int64
# Data.Temperature.Max Temp      int64
# Data.Temperature.Min Temp      int64
# Data.Wind.Direction            int64
# Data.Wind.Speed              float64
# dtype: object

# %%
df2 = pd.read_csv('HR_comma_sep.csv')

# %%
df2['Department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
df2['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
df2.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# dtype: object

# %%
dataframe -- object --str

# %%
df2['newcol'] = 'python'

# %%
df2
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df2.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# newcol                    object
# dtype: object

# %%
df2['salary'] = df2['salary'].map({'low':1,'mediuim':2,'high':3})

# %%
df2.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                   float64
# newcol                    object
# dtype: object

# %%
df2.isnull().sum()
# Out:
# satisfaction_level          0
# last_evaluation             0
# number_project              0
# average_montly_hours        0
# time_spend_company          0
# Work_accident               0
# left                        0
# promotion_last_5years       0
# Department                  0
# salary                   6446
# newcol                      0
# dtype: int64

# %%
df2.dropna(inplace=True)

# %%
df2.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# newcol                   0
# dtype: int64

# %%
df2['salary'] = df2['salary'].astype('int')

# %%
df2.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                     int32
# newcol                    object
# dtype: object

# %%
df2
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 3                       223                   5              0     1
# ...

# %%
#drop

1.df.drop ---> delete 

        col
        rows

# %%
df1.drop()
# Out:
#    Unnamed: 0    city  temp       date  humidity
# 0           0     NaN  34.0  2021/1/24        35
# 1           1  mumbai   NaN  2021/2/25        67
# 2           2     NaN  23.0  2021/3/26        97

# %%
df1.dropna(how='any',subset=['temp'])
# Out:
#    Unnamed: 0 city  temp       date  humidity
# 0           0  NaN  34.0  2021/1/24        35
# 2           2  NaN  23.0  2021/3/26        97

# %%
df1
# Out:
#    Unnamed: 0    city  temp       date  humidity
# 0           0     NaN  34.0  2021/1/24        35
# 1           1  mumbai   NaN  2021/2/25        67
# 2           2     NaN  23.0  2021/3/26        97

# %%
import numpy as np
df1['city'].replace(0,value=null,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-b228a9e1de99> in <module>
#       1 import numpy as np
# ----> 2 df1['city'].replace(0,value=null,inplace=True)
#
# NameError: name 'null' is not defined

# %%
df1
# Out:
#    Unnamed: 0    city  temp       date  humidity
# 0           0     NaN  34.0  2021/1/24        35
# 1           1  mumbai   NaN  2021/2/25        67
# 2           2     NaN  23.0  2021/3/26        97

# %%
df1.replace(0,value=np.nan)
# Out:
#    Unnamed: 0    city  temp       date  humidity
# 0         NaN     NaN  34.0  2021/1/24        35
# 1         1.0  mumbai   NaN  2021/2/25        67
# 2         2.0     NaN  23.0  2021/3/26        97

# %%
df1['temp'] = df1['temp'].replace({'temp':0,
                                  'city':'pune'},np.nan)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-aa706211028f> in <module>
# ----> 1 df1['temp'] = df1['temp'].replace({'temp':0,
#       2                                   'city':'pune'},np.nan)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4955         method: str | lib.NoDefault = lib.no_default,
#    4956     ):
# -> 4957         return super().replace(
#    4958             to_replace=to_replace,
#    4959             value=value,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6683                     # Operate column-wise
#    6684                     if self.ndim == 1:
# -> 6685                         raise ValueError(
# ...

# %%
df1
# Out:
#    Unnamed: 0    city  temp       date  humidity
# 0           0     NaN  34.0  2021/1/24        35
# 1           1  mumbai   NaN  2021/2/25        67
# 2           2     NaN  23.0  2021/3/26        97

# %%
df1.replace(np.nan,{'temp':0,'city':'python'})
# Out:
#    Unnamed: 0    city  temp       date  humidity
# 0           0  python  34.0  2021/1/24        35
# 1           1  mumbai   0.0  2021/2/25        67
# 2           2  python  23.0  2021/3/26        97

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0    0
# city          2
# temp          1
# date          0
# humidity      0
# dtype: int64

# %%
df1.fillna(0)
# Out:
#    Unnamed: 0    city  temp       date  humidity
# 0           0       0  34.0  2021/1/24        35
# 1           1  mumbai   0.0  2021/2/25        67
# 2           2       0  23.0  2021/3/26        97

# %%
df.isnull().sum()
# Out:
# Data.Precipitation           0
# Date.Full                    0
# Date.Month                   0
# Date.Week of                 0
# Date.Year                    0
# Station.City                 0
# Station.Code                 0
# Station.Location             0
# Station.State                0
# Data.Temperature.Avg Temp    0
# Data.Temperature.Max Temp    0
# Data.Temperature.Min Temp    0
# Data.Wind.Direction          0
# Data.Wind.Speed              0
# dtype: int64

# %%
df
# Out:
#       Data.Precipitation,"Date.Full","Date.Month","Date.Week of","Date.Year","Station.City","Station.Code","Station.Location","Station.State","Data.Temperature.Avg Temp","Data.Temperature.Max Temp","Data.Temperature.Min Temp","Data.Wind.Direction","Data.Wind.Speed"
# 0      0.0,"2016-01-03","1","3","2016","Birmingham","...
# 1      0.0,"2016-01-03","1","3","2016","Huntsville","...
# 2      0.16,"2016-01-03","1","3","2016","Mobile","MOB...
# 3      0.0,"2016-01-03","1","3","2016","Montgomery","...
# 4      0.01,"2016-01-03","1","3","2016","Anchorage","...
# ...                                                  ...
# 16738  0.08,"2017-01-01","1","1","2017","Casper","CPR...
# 16739  0.0,"2017-01-01","1","1","2017","Cheyenne","CY...
# 16740  0.0,"2017-01-01","1","1","2017","Lander","LND"...
# 16741  0.06,"2017-01-01","1","1","2017","Rawlins","RW...
# 16742  0.1,"2017-01-01","1","1","2017","Sheridan","SH...
#
# [16743 rows x 1 columns]

# %%
df4 = pd.read_csv('Iris.csv')

# %%
df4.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df5 = pd.read_csv('creditcard.csv')

# %%
df5.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
d = {'name':['gold','silver','iron ore','copper'],
    'price':[45,34,np.nan,55],
    'city':['pune','mumbai',np.nan,'mumbai']}

# %%
d
# Out:
# {'name': ['gold', 'silver', 'iron ore', 'copper'],
#  'price': [45, 34, nan, 55],
#  'city': ['pune', 'mumbai', nan, 'mumbai']}

# %%
df6 = pd.DataFrame(d)

# %%
df6
# Out:
#        name  price    city
# 0      gold   45.0    pune
# 1    silver   34.0  mumbai
# 2  iron ore    NaN     NaN
# 3    copper   55.0  mumbai

# %%
df6.replace(121212,value=np.NaN)
# Out:
#        name  price    city
# 0      gold   45.0    pune
# 1    silver   34.0  mumbai
# 2  iron ore    NaN     NaN
# 3    copper   55.0  mumbai

# %%
df6.replace(np.nan,0,inplace=True)

# %%
df6
# Out:
#        name  price    city
# 0      gold   45.0    pune
# 1    silver   34.0  mumbai
# 2  iron ore    0.0       0
# 3    copper   55.0  mumbai

# %%
df6.replace(['pune','mumbai','gold'],[1,2,3],inplace=True)

# %%
df6
# Out:
#        name  price  city
# 0         3   45.0     1
# 1    silver   34.0     2
# 2  iron ore    0.0     0
# 3    copper   55.0     2

# %%
df6.replace({'city':''},'python',regex=True)
# Out:
#        name  price  city
# 0         3   45.0     1
# 1    silver   34.0     2
# 2  iron ore    0.0     0
# 3    copper   55.0     2

# %%
# Out:
# name      object
# price    float64
# city       int64
# dtype: object

# %%
df6
# Out:
#        name  price  city
# 0         3   45.0     1
# 1    silver   34.0     2
# 2  iron ore    0.0     0
# 3    copper   55.0     2

# %%
df6
# Out:
#        name  price  city
# 0         3   45.0     1
# 1    silver   34.0     2
# 2  iron ore    0.0     0
# 3    copper   55.0     2

# %%
df2
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 3                       223                   5              0     1
# ...

# %%
df2
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 3                       223                   5              0     1
# ...

# %%
obj = df2.groupby('Department')

# %%
obj.get_group('sales')
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# ...                   ...              ...             ...
# 14963                0.09             0.95               6
# 14964                0.10             0.97               6
# 14965                0.45             0.46               2
# 14966                0.83             0.81               5
# 14967                0.43             0.51               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 3                       223                   5              0     1
# ...

# %%
for dept,data in obj:
    print(dept)
    print(data)
# Out:
# IT
#        satisfaction_level  last_evaluation  number_project  \
# 138                  0.74             1.00               4
# 139                  0.73             0.87               5
# 140                  0.09             0.96               6
# 141                  0.45             0.53               2
# 142                  0.11             0.80               6
# ...                   ...              ...             ...
# 14807                0.86             0.84               5
# 14808                0.11             0.90               6
# 14809                0.37             0.46               2
# 14810                0.11             0.92               7
# 14815                0.11             0.79               6
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 138                     249                   5              0     1
# 139                     257                   5              0     1
# ...

# %%
obj

# %%
obj.get_group('IT')
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 138                  0.74             1.00               4
# 139                  0.73             0.87               5
# 140                  0.09             0.96               6
# 141                  0.45             0.53               2
# 142                  0.11             0.80               6
# ...                   ...              ...             ...
# 14807                0.86             0.84               5
# 14808                0.11             0.90               6
# 14809                0.37             0.46               2
# 14810                0.11             0.92               7
# 14815                0.11             0.79               6
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 138                     249                   5              0     1
# 139                     257                   5              0     1
# ...

# %%
obj.mean()
# Out:
#              satisfaction_level  last_evaluation  number_project  \
# Department
# IT                     0.613468         0.715780        3.803468
# RandD                  0.619349         0.712506        3.800000
# accounting             0.580995         0.715718        3.819444
# hr                     0.616289         0.720895        3.715789
# management             0.634395         0.714494        3.777778
# marketing              0.603299         0.716971        3.697095
# product_mng            0.620019         0.717958        3.809249
# sales                  0.606305         0.708176        3.769426
# support                0.598648         0.718904        3.787879
# technical              0.598366         0.720312        3.877305
#
#              average_montly_hours  time_spend_company  Work_accident  \
# Department
# IT                     200.608382            3.394509       0.134393
# RandD                  198.869880            3.400000       0.192771
# ...

# %%
obj.max()
# Out:
#              satisfaction_level  last_evaluation  number_project  \
# Department
# IT                          1.0              1.0               7
# RandD                       1.0              1.0               7
# accounting                  1.0              1.0               7
# hr                          1.0              1.0               7
# management                  1.0              1.0               7
# marketing                   1.0              1.0               7
# product_mng                 1.0              1.0               7
# sales                       1.0              1.0               7
# support                     1.0              1.0               7
# technical                   1.0              1.0               7
#
#              average_montly_hours  time_spend_company  Work_accident  left  \
# Department
# IT                            308                  10              1     1
# ...

# %%
obj.size()
# Out:
# Department
# IT              692
# RandD           415
# accounting      432
# hr              380
# management      405
# marketing       482
# product_mng     519
# sales          2368
# support        1287
# technical      1573
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
obj.plot()
# Out:
# Department
# IT             AxesSubplot(0.125,0.125;0.775x0.755)
# RandD          AxesSubplot(0.125,0.125;0.775x0.755)
# accounting     AxesSubplot(0.125,0.125;0.775x0.755)
# hr             AxesSubplot(0.125,0.125;0.775x0.755)
# management     AxesSubplot(0.125,0.125;0.775x0.755)
# marketing      AxesSubplot(0.125,0.125;0.775x0.755)
# product_mng    AxesSubplot(0.125,0.125;0.775x0.755)
# sales          AxesSubplot(0.125,0.125;0.775x0.755)
# support        AxesSubplot(0.125,0.125;0.775x0.755)
# technical      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
obj.min()
# Out:
#              satisfaction_level  last_evaluation  number_project  \
# Department
# IT                         0.09             0.37               2
# RandD                      0.09             0.36               2
# accounting                 0.09             0.36               2
# hr                         0.09             0.37               2
# management                 0.09             0.37               2
# marketing                  0.09             0.38               2
# product_mng                0.09             0.36               2
# sales                      0.09             0.36               2
# support                    0.09             0.36               2
# technical                  0.09             0.36               2
#
#              average_montly_hours  time_spend_company  Work_accident  left  \
# Department
# IT                             96                   2              0     0
# ...

# %%
obj.get_group('IT').number_project.max()
# Out:
# 7

# %%
obj.get_group('sales').time_spend_company.max()
# Out:
# 10

# %%
df
# Out:
#       Data.Precipitation,"Date.Full","Date.Month","Date.Week of","Date.Year","Station.City","Station.Code","Station.Location","Station.State","Data.Temperature.Avg Temp","Data.Temperature.Max Temp","Data.Temperature.Min Temp","Data.Wind.Direction","Data.Wind.Speed"
# 0      0.0,"2016-01-03","1","3","2016","Birmingham","...
# 1      0.0,"2016-01-03","1","3","2016","Huntsville","...
# 2      0.16,"2016-01-03","1","3","2016","Mobile","MOB...
# 3      0.0,"2016-01-03","1","3","2016","Montgomery","...
# 4      0.01,"2016-01-03","1","3","2016","Anchorage","...
# ...                                                  ...
# 16738  0.08,"2017-01-01","1","1","2017","Casper","CPR...
# 16739  0.0,"2017-01-01","1","1","2017","Cheyenne","CY...
# 16740  0.0,"2017-01-01","1","1","2017","Lander","LND"...
# 16741  0.06,"2017-01-01","1","1","2017","Rawlins","RW...
# 16742  0.1,"2017-01-01","1","1","2017","Sheridan","SH...
#
# [16743 rows x 1 columns]

# %%
df1
# Out:
#    Unnamed: 0    city  temp       date  humidity
# 0           0     NaN  34.0  2021/1/24        35
# 1           1  mumbai   NaN  2021/2/25        67
# 2           2     NaN  23.0  2021/3/26        97

# %%
df1['city']
# Out:
# 0       NaN
# 1    mumbai
# 2       NaN
# Name: city, dtype: object

# %%
df1.city
# Out:
# 0       NaN
# 1    mumbai
# 2       NaN
# Name: city, dtype: object

# %%
df6
# Out:
#        name  price  city
# 0         3   45.0     1
# 1    silver   34.0     2
# 2  iron ore    0.0     0
# 3    copper   55.0     2

# %%
df6.rename({'name':'Product Name'},axis=1,inplace=True)

# %%
df6.city
# Out:
# 0    1
# 1    2
# 2    0
# 3    2
# Name: city, dtype: int64

# %%
df6
# Out:
#   Product Name  price  city
# 0            3   45.0     1
# 1       silver   34.0     2
# 2     iron ore    0.0     0
# 3       copper   55.0     2

# %%
df6.price
# Out:
# 0    45.0
# 1    34.0
# 2     0.0
# 3    55.0
# Name: price, dtype: float64

# %%
df6['Product Name']
# Out:
# 0           3
# 1      silver
# 2    iron ore
# 3      copper
# Name: Product Name, dtype: object

# %%
#df concat

# %%
df7 = pd.DataFrame({'name':['Akash','Sonali','Pranit','Praksh'],
                   'sal':[2344,5677,3344,6788],
                   'city':['pune','kolhapur','aurngabad','pune']})

# %%
df7
# Out:
#      name   sal       city
# 0   Akash  2344       pune
# 1  Sonali  5677   kolhapur
# 2  Pranit  3344  aurngabad
# 3  Praksh  6788       pune

# %%
df8 = pd.DataFrame({'name':['jon','justin','jacky','bob'],
                   'sal':[353,56746467,7675,678242428],
                   'city':['SG','AU','US','CH'],
                   'in':[3252,5678657,21321,686]})

# %%
df8
# Out:
#      name        sal city       in
# 0     jon        353   SG     3252
# 1  justin   56746467   AU  5678657
# 2   jacky       7675   US    21321
# 3     bob  678242428   CH      686

# %%
df7 = pd.concat([df7,df8],keys=['India','Forein'])

# %%
df9
# Out:
#             name        sal       city         in
# India  0   Akash       2344       pune        NaN
#        1  Sonali       5677   kolhapur        NaN
#        2  Pranit       3344  aurngabad        NaN
#        3  Praksh       6788       pune        NaN
# Forein 0     jon        353         SG     3252.0
#        1  justin   56746467         AU  5678657.0
#        2   jacky       7675         US    21321.0
#        3     bob  678242428         CH      686.0

# %%
# Out:
#      name   sal       city  in
# 0   Akash  2344       pune NaN
# 1  Sonali  5677   kolhapur NaN
# 2  Pranit  3344  aurngabad NaN
# 3  Praksh  6788       pune NaN

# %%
df7
# Out:
#             name        sal       city         in
# India  0   Akash       2344       pune        NaN
#        1  Sonali       5677   kolhapur        NaN
#        2  Pranit       3344  aurngabad        NaN
#        3  Praksh       6788       pune        NaN
# Forein 0     jon        353         SG     3252.0
#        1  justin   56746467         AU  5678657.0
#        2   jacky       7675         US    21321.0
#        3     bob  678242428         CH      686.0

# %%
df1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df1
# Out:
#      city  temp       date  humidity
# 0     NaN  34.0  2021/1/24        35
# 1  mumbai   NaN  2021/2/25        67
# 2     NaN  23.0  2021/3/26        97

# %%
df1.columns = ['1','2','3','4']

# %%
df1
# Out:
#         1     2          3   4
# 0     NaN  34.0  2021/1/24  35
# 1  mumbai   NaN  2021/2/25  67
# 2     NaN  23.0  2021/3/26  97

# %%
df7
# Out:
#             name        sal       city         in
# India  0   Akash       2344       pune        NaN
#        1  Sonali       5677   kolhapur        NaN
#        2  Pranit       3344  aurngabad        NaN
#        3  Praksh       6788       pune        NaN
# Forein 0     jon        353         SG     3252.0
#        1  justin   56746467         AU  5678657.0
#        2   jacky       7675         US    21321.0
#        3     bob  678242428         CH      686.0

# %%
df1
# Out:
#         1     2          3   4
# 0     NaN  34.0  2021/1/24  35
# 1  mumbai   NaN  2021/2/25  67
# 2     NaN  23.0  2021/3/26  97

# %%
newcol = pd.Series([100,200,300],name='cat')

# %%
newcol
# Out:
# 0    100
# 1    200
# 2    300
# Name: cat, dtype: int64

# %%
df1 = pd.concat([df1,newcol],axis=1)

# %%
df1
# Out:
#         1     2          3   4  cat
# 0     NaN  34.0  2021/1/24  35  100
# 1  mumbai   NaN  2021/2/25  67  200
# 2     NaN  23.0  2021/3/26  97  300

# %%
df1.set_index('cat')
# Out:
#           1     2          3   4
# cat
# 100     NaN  34.0  2021/1/24  35
# 200  mumbai   NaN  2021/2/25  67
# 300     NaN  23.0  2021/3/26  97

# %%
# Out:
#         1     2          3   4  cat
# 0     NaN  34.0  2021/1/24  35  100
# 1  mumbai   NaN  2021/2/25  67  200
# 2     NaN  23.0  2021/3/26  97  300
